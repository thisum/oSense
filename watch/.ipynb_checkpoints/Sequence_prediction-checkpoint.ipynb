# %%
import numpy as np
import pandas as pd
from scipy import pi
import matplotlib.pyplot as plt
from scipy import fftpack
from scipy import hamming
from scipy import signal
import os
from hmmlearn import hmm
# %matplotlib inline

# %%
raw_data = pd.read_csv("/Users/thisum/Desktop/MagicHand_Data/sequence_data/accel_test.csv", header=None)
raw_data = raw_data[raw_data[3].isin(['bottle'])]
obj_class = raw_data.loc[:, 3]
accel_data = raw_data.loc[:, :2]

# %%
plt.figure(figsize=(20, 5))
plt.plot(accel_data[1])

# %%
f, t, Sxx = signal.spectrogram(accel_data[0], fs=35, nperseg=8, noverlap=7, mode='psd')
plt.figure(figsize=(20, 10))
plt.pcolormesh(t, f, Sxx)
plt.title("8 frames")
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')

# %%
import scipy.fftpack

# %%
N = 100 # Number of samplepoints
T = 1.0 / 35.0 # sample spacing
x = np.linspace(0.0, N*T, N)
avg = np.mean(accel_data[0][0:N])
y = [i - avg for i in accel_data[0][N:2*N]]#np.sin(50.0 * 2.0*np.pi*x)
yf = scipy.fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
plt.figure(figsize=(20, 10))
plt.plot(y)

hamm = np.hamming(len(y))
yf = scipy.fftpack.fft(y*hamm)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
plt.figure(figsize=(20, 10))
plt.plot(xf, 2.0/N * np.abs(yf[:N//2]))

plt.show()
# Out:
# /Users/thisum/Library/Python/3.6/lib/python/site-packages/ipykernel_launcher.py:9: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   if __name__ == '__main__':
# /Users/thisum/Library/Python/3.6/lib/python/site-packages/ipykernel_launcher.py:15: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   from ipykernel import kernelapp as app

# %%
flat = yf.real.flatten()
flat.sort()

# %%
n = list(yf.real).index(flat[-1])
n*(1.0/(T))/yf.size
# Out:
# 9.45

# %%
abs(yf[n])**2
# Out:
# 0.75363656565090154

# %%
np.sum([abs(yf[x])**2 for x in range(int(np.floor(0.3*T*yf.size)), int(np.ceil(10*T*yf.size)))])
# Out:
# 3.1522848918306012

# %%
# Out:
# 3.1522848918306012
